# %%
import math
import matplotlib
print("Hello, World!")

x=13
y=7

print(x+y)

s= "luigin1 and mario23"
len(s)
s[0:10]
print(s[0:10])
print(s)

l=[1,2,3,4]
l.append(5)
print(l)

def func0():
    print ("I am legend")
func0()
func0()
if x%2 !=0: 
    print ("is odd")
elif y%2 ==0:
    print ("is even")
else: print ("is odd")
# Out:
# Hello, World!
# 20
# luigin1 an
# luigin1 and mario23
# [1, 2, 3, 4, 5]
# I am legend
# I am legend
# is odd
